# %% [markdown]
# <a href="https://colab.research.google.com/github/piysinha/Python-Practice/blob/main/PythonPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(.5)
# Out:
# 0.5

# %%
print(1)
# Out:
# 1

# %%
print("String data type")
# Out:
# String data type

# %%
print(True)
# Out:
# True

# %%
input1 = input();
input2 = input();
ans = int(input1) + int(input2);
print(ans);
print(type(ans));
# Out:
# 5
# 6
# 11
# <class 'int'>

# %%
input3 = int(input());
input4 = int(input());
ans = input3 + input4;
print(ans);
print(type(ans));
# Out:
# 5
# 5
# 10
# <class 'int'>

# %%
#Rule: Python operators try to retain as much information as possible

# %%
2+5.5
# Out:
# 7.5

# %%
10/3
# Out:
# 3.3333333333333335

# %%
2*1.7
# Out:
# 3.4

# %%
#Rule 2: Whenever 1 operand is in float the result will be in float

# %%
10/3
#int/int
#answer in float as the division takes presedence and answer in float instead of int
# Out:
# 3.3333333333333335

# %%
#floored division operator (//)
# x//y = floor(x/y); floor - (closest integer less than or equal to the original value)
print(10/3)
print(10//3)
print(-10/3)
print(-10//3)
# Out:
# 3.3333333333333335
# 3
# -3.3333333333333335
# -4

# %%
import math
print(math.ceil(10/3));
print(math.floor(10/3));
# Out:
# 4
# 3

# %%
print(2**2) #int
print(2**3) #int
print(4**-1) #float
print(25**0.5) #float
print(24**0.5) #float
# Out:
# 4
# 8
# 0.25
# 5.0
# 4.898979485566356

# %%
4 % 7
# Out:
# 4

# %%
7 % 4
# Out:
# 3

# %%
7 % 3
# Out:
# 1

# %%
#Presedence of Operators in Python - Bracket Order Division Multiplication Addition Subtraction

# %%
# Same precedence operator follows from solution from left to right.

# %%
(10 - 4 * 2 + 5 - 6 / 2 ) # ans will be in float in python because of the division operator used.
# Out:
# 4.0

# %%
x = 11
y = 2
z = 4
res = (x + y - z) ** (x % z);
print(res);
# Out:
# 729
